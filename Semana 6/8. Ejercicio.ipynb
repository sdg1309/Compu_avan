# %%
# --- PASO 1: Importa las bibliotecas necesarias ---
# (Completa los espacios con las importaciones correctas)
import numpy as np
from sklearn.datasets import ______
from sklearn.______ import train_test_split
from sklearn.______ import StandardScaler
from sklearn.linear_model import ______
from sklearn.______ import make_pipeline
from sklearn.metrics import ______
from sklearn.neighbors import ______

# --- PASO 2: Carga y divide los datos ---
data = ______.______()
X, y = ______, ______

# Divide en train (60%), validation (20%) y test (20%) con estratificación
X_temp, X_test, y_temp, y_test = train_test_split(
    ______, ______, 
    test_size=______, 
    stratify=______, 
    random_state=42
)
X_train, X_val, y_train, y_val = train_test_split(
    ______, ______, 
    test_size=______,  # Calcula para que validation sea 20% del total
    stratify=______,
    random_state=42
)

# --- PASO 3: Entrenamiento con pipeline ---
# Crea un pipeline con StandardScaler y LogisticRegression
pipe_lr = make_pipeline(
    ______(), 
    ______(max_iter=1000)
)

# Crea un segundo pipeline con StandardScaler y KNeighborsClassifier (n_neighbors=5)
pipe_knn = ______(
    ______(),
    ______(n_neighbors=______)
)

# Entrena ambos modelos
______.______(X_train, y_train)
______.______(X_train, y_train)

# --- PASO 4: Evaluación ---
# Evalúa ambos modelos en el validation set
y_pred_val_lr = ______.______(X_val)
y_pred_val_knn = ______.______(X_val)

print("Precisión Regresión Logística (validation):", 
      ______(y_val, y_pred_val_lr))
print("Precisión KNN (validation):", 
      ______(y_val, y_pred_val_knn))

# Selecciona el mejor modelo basado en validation
if ______ > ______:
    best_model = ______
    print("\nMejor modelo: Regresión Logística")
else:
    best_model = ______
    print("\nMejor modelo: KNN")

# Evalúa el mejor modelo en el test set (¡SOLO UNA VEZ!)
y_pred_test = ______.______(X_test)
test_accuracy = ______(y_test, y_pred_test)
print(f"\nPrecisión del mejor modelo en TEST: {test_accuracy:.4f}")

# --- PASO 5: Análisis (responde mentalmente) ---
# 1. ¿Por qué fue importante usar stratify?
# 2. ¿Qué modelo funcionó mejor en validation? ¿Se mantuvo igual en test?
# 3. ¿Hubo sobreajuste? (Compara train vs validation vs test)
# 4. ¿Qué pasaría si usáramos todo el dataset para el StandardScaler?

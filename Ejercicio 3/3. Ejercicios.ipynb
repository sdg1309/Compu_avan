# %%
# ejercicios_practicos.py
"""
EJERCICIOS PARA PRACTICAR:
1. Manipulación de Pandas
2. Análisis con NumPy
3. Visualización con Matplotlib
"""

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# -------------------------------------------
# EJERCICIO 1: CREACIÓN Y MANIPULACIÓN BÁSICA
# -------------------------------------------
print("="*50)
print("EJERCICIO 1: CREACIÓN Y MANIPULACIÓN BÁSICA")
print("="*50)

# 1a. Crea una Serie de temperaturas diarias (ºC) para una semana
#     Valores: [22.5, 23.0, 24.5, 21.0, 20.5, 19.0, 18.5]
#     Índices: ['Lun', 'Mar', 'Mie', 'Jue', 'Vie', 'Sab', 'Dom']

# Crear DataFrames desde diferentes fuentes
datos = {
    'Temps': [22.5, 23.0, 24.5, 21.0, 20.5, 19.0, 18.5],
    'Dia': ['Lun', 'Mar', 'Mie', 'Jue', 'Vie', 'Sab', 'Dom']
}

df_temps = pd.DataFrame(datos)

# 1b. Convierte la Serie a DataFrame con columna "Temperatura"
print('\n Data frame inicial')
print(df_temps)

# 1c. Añade una nueva columna "Humedad_rel" con valores:
#     [45, 50, 55, 60, 65, 70, 75]
df_temps['Humedad_rel'] = [45, 50, 55, 60, 65, 70, 75]
print('\n Data frame con la humedad')
print(df_temps)


# 1d. Filtra los días con temperatura > 22ºC
print('\n Dias con temperatuta mayor a 22ºC')
print(df_temps[df_temps['Temps'] > 22.0])


# 1e. Calcula la temperatura promedio usando Pandas
print('\n La temperatutra promedio es:')
print(df_temps['Temps'].mean())
# Out:
# ...
# EJERCICIO 1: CREACIÓN Y MANIPULACIÓN BÁSICA
# ...
#
#  Data frame inicial
#    Temps  Dia
# 0   22.5  Lun
# 1   23.0  Mar
# 2   24.5  Mie
# 3   21.0  Jue
# 4   20.5  Vie
# 5   19.0  Sab
# 6   18.5  Dom
#
#  Data frame con la humedad
#    Temps  Dia  Humedad_rel
# 0   22.5  Lun           45
# 1   23.0  Mar           50
# 2   24.5  Mie           55
# 3   21.0  Jue           60
# 4   20.5  Vie           65
# 5   19.0  Sab           70
# 6   18.5  Dom           75
#
#  Dias con temperatuta mayor a 22ºC
#    Temps  Dia  Humedad_rel
# 0   22.5  Lun           45
# 1   23.0  Mar           50
# 2   24.5  Mie           55
#
#  La temperatutra promedio es:
# 21.285714285714285

# %%
# -------------------------------------------
# EJERCICIO 2: OPERACIONES CON NUMPY Y PANDAS
# -------------------------------------------
print("\n" + "="*50)
print("EJERCICIO 2: OPERACIONES CON NUMPY Y PANDAS")
print("="*50)

# 2a. Crea un array de NumPy con 20 valores aleatorios entre 0 y 100
#     Pista: np.random.randint()


Numero_alea = []
Numero_alea.append(np.random.randint(0, 10, 20))

print('\n Array de numeros aleatorios')
print(Numero_alea)

# 2b. Convierte el array a DataFrame con columna "Valores"

df_rand = pd.DataFrame(Numero_alea), columns=['Valores']

print(df_rand)

# 2c. Añade una columna "Categoria" que clasifique los valores:
#     'Bajo' (0-33), 'Medio' (34-66), 'Alto' (67-100)
#     Pista: Usar pd.cut()

# 2d. Calcula usando NumPy:
#     - Media de valores
#     - Desviación estándar
#     - Valor máximo
# Out:
#   Cell In[26], line 20
#     df_rand = pd.DataFrame(Numero_alea), columns=['Valores']
#     ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
# -------------------------------------------
# EJERCICIO 3: VISUALIZACIÓN CON MATPLOTLIB
# -------------------------------------------
print("\n" + "="*50)
print("EJERCICIO 3: VISUALIZACIÓN CON MATPLOTLIB")
print("="*50)

# Datos para los ejercicios:
ventas = {
    'Mes': ['Ene', 'Feb', 'Mar', 'Abr'],
    'Producto_A': [120, 135, 124, 156],
    'Producto_B': [85, 92, 98, 110]
}
df_ventas = pd.DataFrame(ventas)

# 3a. Crea un gráfico de líneas doble:
#     - Eje X: Meses
#     - Eje Y: Ventas
#     - Dos líneas: Producto_A (rojo) y Producto_B (azul)
#     - Añade leyenda, título y etiquetas de ejes

# 3b. Genera un histograma de los valores del Ejercicio 2
#     con 5 bins y color verde

# 3c. Gráfico de barras comparando ventas totales por mes
#     (Suma de Producto_A + Producto_B)

# -------------------------------------------
# EJERCICIO 4: ANÁLISIS COMBINADO (DESAFÍO)
# -------------------------------------------
print("\n" + "="*50)
print("EJERCICIO 4: ANÁLISIS COMBINADO (DESAFÍO)")
print("="*50)

# 4a. Crea un DataFrame con 100 filas y 3 columnas:
#     - 'X': valores aleatorios normales (media=0, std=1)
#     - 'Y': 2*X + ruido aleatorio (normal, std=0.5)
#     - 'Z': X^2 + Y + ruido aleatorio (normal, std=0.3)

# 4b. Calcula:
#     - Correlación entre X e Y (Pandas)
#     - Ecuación de regresión lineal (NumPy: np.polyfit)

# 4c. Visualiza:
#     - Scatter plot de X vs Y con Matplotlib
#     - Superponer la línea de regresión
#     - Añadir ecuación en el gráfico

# SOLUCIONES (¡Comprueba después de intentarlo!)
"""
Las soluestas están disponibles en:
https://gist.github.com/deepseek-ai-examples/1234567890abcdef
(Pedirme el enlace real si lo necesitas)
"""
